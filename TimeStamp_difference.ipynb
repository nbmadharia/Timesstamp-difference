# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_excel("/home/administor/Downloads/Book1.xlsx")
df
# Out:
#     Unnamed: 0  max_infection_rate  GDP per capita  Social support  \
# 0  Afghanistan                 232           0.350           0.517
# 1      Albania                  34           0.947           0.848
# 2      Algeria                 199           1.002           1.160
# 3    Argentina                 291           1.092           1.432
# 4      Armenia                 134           0.850           1.055
# 5      America               10024           0.750           2.440
#
#    Healthy life expectancy  Freedom to make life choices     date 1  \
# 0                    0.361                         0.000 2020-02-08
# 1                    0.874                         0.383 2020-05-04
# 2                    0.785                         0.086 2020-04-03
# 3                    0.881                         0.471 2020-01-01
# 4                    0.815                         0.283 2020-06-07
# 5                    0.530                         0.660 2020-03-03
#
# ...

# %%
#declaration
list1=[] #location for date columns
print(df.dtypes[-1])
# Out:
# datetime64[ns]

# %%
#x=df[df.columns[-1]
len(list1)
# Out:
# 0

# %%
#type(df[df.columns[-1]][0])
for i in range(10):
    if df.dtypes[i] == 'datetime64[ns]':
        list1.append(i)
list1.append(list1[0])
print(list1," this indexes has date values inside them" )
len(list1)
# Out:
# [6, 7, 8, 9, 6]  this indexes has date values inside them
# 5

# %%
# we have to add column names manually as we cannot add automatically because it overwrites in the values 
df=df.assign(date1date2= lambda y:abs(df[df.columns[list1[0]]] - df[df.columns[list1[1]]]))
df=df.assign(date2date3= lambda y:abs(df[df.columns[list1[1]]] - df[df.columns[list1[2]]]))
df=df.assign(date3date4= lambda y:abs(df[df.columns[list1[2]]] - df[df.columns[list1[3]]]))
df=df.assign(date4date1= lambda y:abs(df[df.columns[list1[3]]] - df[df.columns[list1[4]]]))
df
# Out:
#     Unnamed: 0  max_infection_rate  GDP per capita  Social support  \
# 0  Afghanistan                 232           0.350           0.517
# 1      Albania                  34           0.947           0.848
# 2      Algeria                 199           1.002           1.160
# 3    Argentina                 291           1.092           1.432
# 4      Armenia                 134           0.850           1.055
# 5      America               10024           0.750           2.440
#
#    Healthy life expectancy  Freedom to make life choices     date 1  \
# 0                    0.361                         0.000 2020-02-08
# 1                    0.874                         0.383 2020-05-04
# 2                    0.785                         0.086 2020-04-03
# 3                    0.881                         0.471 2020-01-01
# 4                    0.815                         0.283 2020-06-07
# 5                    0.530                         0.660 2020-03-03
#
# ...
